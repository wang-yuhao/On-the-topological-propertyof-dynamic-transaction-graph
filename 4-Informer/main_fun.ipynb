# %%
import sys
import sys
if not 'Informer2020' in sys.path:
    sys.path += ['Informer2020']

from utils.tools import dotdict
from exp.exp_informer import Exp_Informer
import torch
if not 'Informer2020' in sys.path:
    sys.path += ['Informer2020']

from utils.tools import dotdict
from exp.exp_informer import Exp_Informer
import torch

args = dotdict()

args.model = 'informer' # model of experiment, options: [informer, informerstack, informerlight(TBD)]

args.data = 'custom' # data
args.root_path = '/root/study/ChainMT/Informer/processed_data/2017/' # root path of data file
#args.data_path = 'betti.csv' # data file
#args.data_path = 'betti_der.csv' # data file
#args.data_path = 'fl.csv' # data file
args.data_path = 'base.csv'
args.features = 'MS' # forecasting task, options:[M, S, MS]; M:multivariate predict multivariate, S:univariate predict univariate, MS:multivariate predict univariate
args.target = 'price' # target feature in S or MS task
args.freq = 'h' # freq for time features encoding, options:[s:secondly, t:minutely, h:hourly, d:daily, b:business days, w:weekly, m:monthly], you can also use more detailed freq like 15min or 3h
args.checkpoints = './informer_checkpoints' # location of model checkpoints

args.seq_len = 2 # input sequence length of Informer encoder
args.label_len = 1 # start token length of Informer decoder
args.pred_len = 10 # prediction sequence length
# Informer decoder input: concat[start token series(label_len), zero padding series(pred_len)]

args.enc_in = 7 # encoder input size
args.dec_in = 7 # decoder input size
args.c_out = 7 # output size
args.factor = 5 # probsparse attn factor
args.d_model = 512 # dimension of model
args.n_heads = 8 # num of heads
args.e_layers = 2 # num of encoder layers
args.d_layers = 1 # num of decoder layers
args.d_ff = 2048 # dimension of fcn in model
args.dropout = 0.05 # dropout
args.attn = 'prob' # attention used in encoder, options:[prob, full]
args.embed = 'timeF' # time features encoding, options:[timeF, fixed, learned]
args.activation = 'gelu' # activation
args.distil = True # whether to use distilling in encoder
args.output_attention = False # whether to output attention in ecoder

#args.batch_size = 32 
args.batch_size = 7
args.learning_rate = 0.0001

#args.loss = 'mse'
args.loss = 'rmse'
args.lradj = 'type1'
args.use_amp = False # whether to use automatic mixed precision training

args.num_workers = 0
args.itr = 1
args.train_epochs = 6
args.patience = 3
args.des = 'exp'

args.use_gpu = True if torch.cuda.is_available() else False
args.gpu = 0

args.use_multi_gpu = False
args.devices = '0,1,2,3'

# %%
args.use_gpu = True if torch.cuda.is_available() and args.use_gpu else False

if args.use_gpu and args.use_multi_gpu:
    args.dvices = args.devices.replace(' ','')
    device_ids = args.devices.split(',')
    args.device_ids = [int(id_) for id_ in device_ids]
    args.gpu = args.device_ids[0]

def select_data(dataset_model):
    # Set augments by using data name
    if(dataset_model=='base'):
        data_parser = {
            'custom':{'data':'base.csv','T':'price','M':[2,2,2],'S':[1,1,1],'MS':[2,2,1]}, # base
        }
    elif(dataset_model=='betti'):
        data_parser = {
            'custom':{'data':'betti.csv','T':'price','M':[22,22,22],'S':[1,1,1],'MS':[22,22,1]}, # betti
        }
    elif(dataset_model=='betti_der'):
        data_parser = {
            'custom':{'data':'betti_der.csv','T':'price','M':[22,22,22],'S':[1,1,1],'MS':[22,22,1]}, # betti derivate
        }
    elif(dataset_model=='fl'):
        data_parser = {
            'custom':{'data':'fl.csv','T':'price','M':[22,22,22],'S':[1,1,1],'MS':[22,22,1]}, # fl
        }

    if args.data in data_parser.keys():
        data_info = data_parser[args.data]
        args.data_path = data_info['data']
        args.target = data_info['T']
        args.enc_in, args.dec_in, args.c_out = data_info[args.features]

    args.detail_freq = args.freq
    args.freq = args.freq[-1:]
    print('Args in experiment:')
    print(args)

# %%
import numpy as np
Exp = Exp_Informer
window_arr = [3,5,7]
horizon_arr = [1, 2, 5, 7, 10, 15, 20, 25, 30]
dataset_model_array = ["base","betti", "betti_der","fl"]
rmse_total = np.zeros([4, 3, 9])
i = 0
for dataset_model in dataset_model_array:
    args.data_path = dataset_model + '.csv'
    select_data(dataset_model)
    j = 0
    for args.seq_len in window_arr:
        n = 0
        for args.pred_len in horizon_arr:
            for ii in range(args.itr):
                # setting record of experiments
                setting = '{}_{}_ft{}_sl{}_ll{}_pl{}_dm{}_nh{}_el{}_dl{}_df{}_at{}_fc{}_eb{}_dt{}_{}_{}'.format(args.model, args.data, args.features, 
                            args.seq_len, args.label_len, args.pred_len,
                            args.d_model, args.n_heads, args.e_layers, args.d_layers, args.d_ff, args.attn, args.factor, args.embed, args.distil, args.des, ii)

                # set experiments
                exp = Exp(args)
                # train
                print('>>>>>>>start training : {}>>>>>>>>>>>>>>>>>>>>>>>>>>'.format(setting))
                exp.train(setting)

                # test
                print('>>>>>>>testing : {}<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<'.format(setting))
                rmse_total[i][j][n] = exp.test(setting)
                

                torch.cuda.empty_cache()
                
            n = n + 1
        j = j + 1
    i = i + 1
# Out:
# Args in experiment:
# {'model': 'informer', 'data': 'custom', 'root_path': '/root/study/ChainMT/Informer/processed_data/2017/', 'data_path': 'base.csv', 'features': 'MS', 'target': 'price', 'freq': 'h', 'checkpoints': './informer_checkpoints', 'seq_len': 3, 'label_len': 1, 'pred_len': 5, 'enc_in': 2, 'dec_in': 2, 'c_out': 1, 'factor': 5, 'd_model': 512, 'n_heads': 8, 'e_layers': 2, 'd_layers': 1, 'd_ff': 2048, 'dropout': 0.05, 'attn': 'prob', 'embed': 'timeF', 'activation': 'gelu', 'distil': True, 'output_attention': False, 'batch_size': 7, 'learning_rate': 0.0001, 'loss': 'rmse', 'lradj': 'type1', 'use_amp': False, 'num_workers': 0, 'itr': 1, 'train_epochs': 6, 'patience': 3, 'des': 'exp', 'use_gpu': False, 'gpu': 0, 'use_multi_gpu': False, 'devices': '0,1,2,3', 'detail_freq': 'h'}
# Use CPU
# >>>>>>>start training : informer_custom_ftMS_sl3_ll1_pl1_dm512_nh8_el2_dl1_df2048_atprob_fc5_ebtimeF_dtTrue_exp_0>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 252
# val 37
# test 73
# Epoch: 1 cost time: 3.402326822280884
# Epoch: 1, Steps: 36 | Train Loss: 0.5101354 Vali Loss: 0.6559972 Test Loss: 44.5255356
# Validation loss decreased (inf --> 0.655997).  Saving model ...
# Updating learning rate to 0.0001
# Epoch: 2 cost time: 3.4440090656280518
# Epoch: 2, Steps: 36 | Train Loss: 0.1049222 Vali Loss: 0.4775710 Test Loss: 43.7325516
# Validation loss decreased (0.655997 --> 0.477571).  Saving model ...
# Updating learning rate to 5e-05
# Epoch: 3 cost time: 3.3778321743011475
# Epoch: 3, Steps: 36 | Train Loss: 0.0400962 Vali Loss: 0.2228668 Test Loss: 38.9056587
# Validation loss decreased (0.477571 --> 0.222867).  Saving model ...
# Updating learning rate to 2.5e-05
# Epoch: 4 cost time: 3.375330924987793
# Epoch: 4, Steps: 36 | Train Loss: 0.0291091 Vali Loss: 0.2223165 Test Loss: 38.9748306
# Validation loss decreased (0.222867 --> 0.222317).  Saving model ...
# Updating learning rate to 1.25e-05
# Epoch: 5 cost time: 3.4021425247192383
# Epoch: 5, Steps: 36 | Train Loss: 0.0282075 Vali Loss: 0.2037456 Test Loss: 38.0193329
# Validation loss decreased (0.222317 --> 0.203746).  Saving model ...
# Updating learning rate to 6.25e-06
# Epoch: 6 cost time: 3.3650245666503906
# Epoch: 6, Steps: 36 | Train Loss: 0.0224419 Vali Loss: 0.1790991 Test Loss: 37.1627960
# Validation loss decreased (0.203746 --> 0.179099).  Saving model ...
# Updating learning rate to 3.125e-06
# >>>>>>>testing : informer_custom_ftMS_sl3_ll1_pl1_dm512_nh8_el2_dl1_df2048_atprob_fc5_ebtimeF_dtTrue_exp_0<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# test 73
# test shape: (10, 7, 1, 1) (10, 7, 1, 1)
# test shape: (70, 1, 1) (70, 1, 1)
# mse:37.16279602050781, rmse:6.096129417419434, mae:4.806412696838379
# Use CPU
# >>>>>>>start training : informer_custom_ftMS_sl3_ll1_pl2_dm512_nh8_el2_dl1_df2048_atprob_fc5_ebtimeF_dtTrue_exp_0>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 251
# val 36
# test 72
# Epoch: 1 cost time: 3.3977551460266113
# Epoch: 1, Steps: 35 | Train Loss: 0.2019023 Vali Loss: 0.3613328 Test Loss: 33.9525681
# Validation loss decreased (inf --> 0.361333).  Saving model ...
# Updating learning rate to 0.0001
# Epoch: 2 cost time: 3.337662935256958
# Epoch: 2, Steps: 35 | Train Loss: 0.0721664 Vali Loss: 0.3225198 Test Loss: 40.3017578
# Validation loss decreased (0.361333 --> 0.322520).  Saving model ...
# Updating learning rate to 5e-05
# Epoch: 3 cost time: 3.3195927143096924
# Epoch: 3, Steps: 35 | Train Loss: 0.0372286 Vali Loss: 0.1720217 Test Loss: 36.4571724
# Validation loss decreased (0.322520 --> 0.172022).  Saving model ...
# Updating learning rate to 2.5e-05
# Epoch: 4 cost time: 3.345445394515991
# Epoch: 4, Steps: 35 | Train Loss: 0.0247931 Vali Loss: 0.1675691 Test Loss: 36.0955353
# Validation loss decreased (0.172022 --> 0.167569).  Saving model ...
# Updating learning rate to 1.25e-05
# Epoch: 5 cost time: 3.482597827911377
# Epoch: 5, Steps: 35 | Train Loss: 0.0227066 Vali Loss: 0.1510149 Test Loss: 36.2231979
# Validation loss decreased (0.167569 --> 0.151015).  Saving model ...
# Updating learning rate to 6.25e-06
# Epoch: 6 cost time: 3.3735756874084473
# Epoch: 6, Steps: 35 | Train Loss: 0.0207192 Vali Loss: 0.1612267 Test Loss: 36.6670685
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 3.125e-06
# >>>>>>>testing : informer_custom_ftMS_sl3_ll1_pl2_dm512_nh8_el2_dl1_df2048_atprob_fc5_ebtimeF_dtTrue_exp_0<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# test 72
# test shape: (10, 7, 2, 1) (10, 7, 2, 1)
# test shape: (70, 2, 1) (70, 2, 1)
# mse:36.22319793701172, rmse:6.018570899963379, mae:4.728914737701416
# Use CPU
# >>>>>>>start training : informer_custom_ftMS_sl3_ll1_pl5_dm512_nh8_el2_dl1_df2048_atprob_fc5_ebtimeF_dtTrue_exp_0>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 248
# val 33
# test 69
# Epoch: 1 cost time: 3.511632204055786
# Epoch: 1, Steps: 35 | Train Loss: 0.4584184 Vali Loss: 0.1782836 Test Loss: 31.6731472
# Validation loss decreased (inf --> 0.178284).  Saving model ...
# Updating learning rate to 0.0001
# Epoch: 2 cost time: 3.5136921405792236
# Epoch: 2, Steps: 35 | Train Loss: 0.1334055 Vali Loss: 0.1804792 Test Loss: 30.9094276
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 5e-05
# Epoch: 3 cost time: 3.5095725059509277
# Epoch: 3, Steps: 35 | Train Loss: 0.0521198 Vali Loss: 0.1748587 Test Loss: 30.1697254
# Validation loss decreased (0.178284 --> 0.174859).  Saving model ...
# Updating learning rate to 2.5e-05
# Epoch: 4 cost time: 3.485989809036255
# Epoch: 4, Steps: 35 | Train Loss: 0.0411047 Vali Loss: 0.1661639 Test Loss: 30.4192772
# Validation loss decreased (0.174859 --> 0.166164).  Saving model ...
# Updating learning rate to 1.25e-05
# Epoch: 5 cost time: 3.49456787109375
# Epoch: 5, Steps: 35 | Train Loss: 0.0379613 Vali Loss: 0.1645472 Test Loss: 30.6979332
# Validation loss decreased (0.166164 --> 0.164547).  Saving model ...
# Updating learning rate to 6.25e-06
# Epoch: 6 cost time:
# EarlyStopping counter: 3 out of 3
# Early stopping
# >>>>>>>testing : informer_custom_ftMS_sl3_ll1_pl25_dm512_nh8_el2_dl1_df2048_atprob_fc5_ebtimeF_dtTrue_exp_0<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# test 49
# test shape: (7, 7, 25, 1) (7, 7, 25, 1)
# test shape: (49, 25, 1) (49, 25, 1)
# mse:29.757190704345703, rmse:5.455015182495117, mae:4.282072067260742
# Use CPU
# >>>>>>>start training : informer_custom_ftMS_sl3_ll1_pl30_dm512_nh8_el2_dl1_df2048_atprob_fc5_ebtimeF_dtTrue_exp_0>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 223
# val 8
# test 44
# Epoch: 1 cost time: 4.113124132156372
# Epoch: 1, Steps: 31 | Train Loss: 0.4693308 Vali Loss: 1.1790938 Test Loss: 42.8293800
# Validation loss decreased (inf --> 1.179094).  Saving model ...
# Updating learning rate to 0.0001
# Epoch: 2 cost time: 4.205144643783569
# Epoch: 2, Steps: 31 | Train Loss: 0.2781700 Vali Loss: 0.6077172 Test Loss: 37.8479309
# Validation loss decreased (1.179094 --> 0.607717).  Saving model ...
# Updating learning rate to 5e-05
# Epoch: 3 cost time: 4.060439348220825
# Epoch: 3, Steps: 31 | Train Loss: 0.1516415 Vali Loss: 0.5387603 Test Loss: 35.1341286
# Validation loss decreased (0.607717 --> 0.538760).  Saving model ...
# Updating learning rate to 2.5e-05
# Epoch: 4 cost time: 4.034762382507324
# Epoch: 4, Steps: 31 | Train Loss: 0.1528503 Vali Loss: 0.4054567 Test Loss: 32.4366074
# Validation loss decreased (0.538760 --> 0.405457).  Saving model ...
# Updating learning rate to 1.25e-05
# Epoch: 5 cost time: 4.120970010757446
# Epoch: 5, Steps: 31 | Train Loss: 0.1333169 Vali Loss: 0.2473972 Test Loss: 30.7777767
# Validation loss decreased (0.405457 --> 0.247397).  Saving model ...
# Updating learning rate to 6.25e-06
# Epoch: 6 cost time: 4.06694221496582
# Epoch: 6, Steps: 31 | Train Loss: 0.1109129 Vali Loss: 0.3021346 Test Loss: 30.3946686
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 3.125e-06
# >>>>>>>testing : informer_custom_ftMS_sl3_ll1_pl30_dm512_nh8_el2_dl1_df2048_atprob_fc5_ebtimeF_dtTrue_exp_0<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# test 44
# test shape: (6, 7, 30, 1) (6, 7, 30, 1)
# test shape: (42, 30, 1) (42, 30, 1)
# mse:30.97658348083496, rmse:5.5656609535217285, mae:4.4772467613220215
# Use CPU
# >>>>>>>start training : informer_custom_ftMS_sl5_ll1_pl1_dm512_nh8_el2_dl1_df2048_atprob_fc5_ebtimeF_dtTrue_exp_0>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 250
# val 37
# test 73
# Epoch: 1 cost time: 3.4972665309906006
# Epoch: 1, Steps: 35 | Train Loss: 0.2555599 Vali Loss: 0.2128609 Test Loss: 36.0202866
# Validation loss decreased (inf --> 0.212861).  Saving model ...
# Updating learning rate to 0.0001
# Epoch: 2 cost time: 3.522099733352661
# Epoch: 2, Steps: 35 | Train Loss: 0.0712762 Vali Loss: 0.1330553 Test Loss: 36.9468613
# Validation loss decreased (0.212861 --> 0.133055).  Saving model ...
# Updating learning rate to 5e-05
# Epoch: 3 cost time: 3.4974544048309326
# Epoch: 3, Steps: 35 | Train Loss: 0.0341982 Vali Loss: 0.1469353 Test Loss: 37.9329910
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 2.5e-05
# Epoch: 4 cost time: 3.464836359024048
# Epoch: 4, Steps: 35 | Train Loss: 0.0364799 Vali Loss: 0.1696339 Test Loss: 37.1421204
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 1.25e-05
# Epoch: 5 cost time: 3.461970567703247
# Epoch: 5, Steps: 35 | Train Loss: 0.0242132 Vali Loss: 0.1698166 Test Loss: 36.7332687
# EarlyStopping counter: 3 out of 3
# Early stopping
# >>>>>>>testing : informer_custom_ftMS_sl5_ll1_pl1_dm512_nh8_el2_dl1_df2048_atprob_fc5_ebtimeF_dtTrue_exp_0<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# test 73
# test shape: (10, 7, 1, 1) (10, 7, 1, 1)
# test shape: (70, 1, 1) (70, 1, 1)
# mse:36.946868896484375, rmse:6.078393459320068, mae:4.762898921966553
# Use CPU
# >>>>>>>start training : informer_custom_ftMS_sl5_ll1_pl2_dm512_nh8_el2_dl1_df2048_atprob_fc5_ebtimeF_dtTrue_exp_0>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 249
# val 36
# test 72
# Epoch: 1 cost time: 3.585361957550049
# Epoch: 1, Steps: 35 | Train Loss: 0.2475696 Vali Loss: 0.2053663 Test Loss: 35.8861122
# Validation loss decreased (inf --> 0.205366).  Saving model ...
# Updating learning rate to 0.0001
# Epoch: 2 cost time: 3.4827191829681396
# Epoch: 2, Steps: 35 | Train Loss: 0.0532041 Vali Loss: 0.1550429 Test Loss: 35.8615952
# Validation loss decreased (0.205366 --> 0.155043).  Saving model ...
# Updating learning rate to 5e-05
# Epoch: 3 cost time: 3
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 2.5e-05
# Epoch: 4 cost time: 4.0776145458221436
# Epoch: 4, Steps: 33 | Train Loss: 0.0783324 Vali Loss: 0.2050171 Test Loss: 21.5948792
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 1.25e-05
# Epoch: 5 cost time: 4.139106035232544
# Epoch: 5, Steps: 33 | Train Loss: 0.0692793 Vali Loss: 0.1602101 Test Loss: 21.5985718
# EarlyStopping counter: 3 out of 3
# Early stopping
# >>>>>>>testing : informer_custom_ftMS_sl5_ll1_pl20_dm512_nh8_el2_dl1_df2048_atprob_fc5_ebtimeF_dtTrue_exp_0<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# test 54
# test shape: (7, 7, 20, 1) (7, 7, 20, 1)
# test shape: (49, 20, 1) (49, 20, 1)
# mse:23.07832908630371, rmse:4.803990840911865, mae:3.5970749855041504
# Use CPU
# >>>>>>>start training : informer_custom_ftMS_sl5_ll1_pl25_dm512_nh8_el2_dl1_df2048_atprob_fc5_ebtimeF_dtTrue_exp_0>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 226
# val 13
# test 49
# Epoch: 1 cost time: 4.289958715438843
# Epoch: 1, Steps: 32 | Train Loss: 0.4184169 Vali Loss: 0.2675314 Test Loss: 40.3868141
# Validation loss decreased (inf --> 0.267531).  Saving model ...
# Updating learning rate to 0.0001
# Epoch: 2 cost time: 4.29498553276062
# Epoch: 2, Steps: 32 | Train Loss: 0.2968454 Vali Loss: 0.3993872 Test Loss: 36.4309082
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 5e-05
# Epoch: 3 cost time: 4.29494833946228
# Epoch: 3, Steps: 32 | Train Loss: 0.1356282 Vali Loss: 0.2337542 Test Loss: 30.0859241
# Validation loss decreased (0.267531 --> 0.233754).  Saving model ...
# Updating learning rate to 2.5e-05
# Epoch: 4 cost time: 4.228240966796875
# Epoch: 4, Steps: 32 | Train Loss: 0.1067025 Vali Loss: 0.2498476 Test Loss: 29.8952503
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 1.25e-05
# Epoch: 5 cost time: 4.278161287307739
# Epoch: 5, Steps: 32 | Train Loss: 0.1005612 Vali Loss: 0.1937354 Test Loss: 28.6657677
# Validation loss decreased (0.233754 --> 0.193735).  Saving model ...
# Updating learning rate to 6.25e-06
# Epoch: 6 cost time: 4.244974374771118
# Epoch: 6, Steps: 32 | Train Loss: 0.0865936 Vali Loss: 0.2241980 Test Loss: 28.8511143
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 3.125e-06
# >>>>>>>testing : informer_custom_ftMS_sl5_ll1_pl25_dm512_nh8_el2_dl1_df2048_atprob_fc5_ebtimeF_dtTrue_exp_0<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# test 49
# test shape: (7, 7, 25, 1) (7, 7, 25, 1)
# test shape: (49, 25, 1) (49, 25, 1)
# mse:28.833051681518555, rmse:5.3696417808532715, mae:4.175137996673584
# Use CPU
# >>>>>>>start training : informer_custom_ftMS_sl5_ll1_pl30_dm512_nh8_el2_dl1_df2048_atprob_fc5_ebtimeF_dtTrue_exp_0>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 221
# val 8
# test 44
# Epoch: 1 cost time: 4.422942399978638
# Epoch: 1, Steps: 31 | Train Loss: 0.6168333 Vali Loss: 1.6071905 Test Loss: 46.5538139
# Validation loss decreased (inf --> 1.607190).  Saving model ...
# Updating learning rate to 0.0001
# Epoch: 2 cost time: 4.27860426902771
# Epoch: 2, Steps: 31 | Train Loss: 0.2301520 Vali Loss: 1.0405151 Test Loss: 41.8434715
# Validation loss decreased (1.607190 --> 1.040515).  Saving model ...
# Updating learning rate to 5e-05
# Epoch: 3 cost time: 4.267827987670898
# Epoch: 3, Steps: 31 | Train Loss: 0.1527810 Vali Loss: 0.4752723 Test Loss: 35.4312286
# Validation loss decreased (1.040515 --> 0.475272).  Saving model ...
# Updating learning rate to 2.5e-05
# Epoch: 4 cost time: 4.183406591415405
# Epoch: 4, Steps: 31 | Train Loss: 0.1262616 Vali Loss: 0.5347572 Test Loss: 34.7796745
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 1.25e-05
# Epoch: 5 cost time: 4.252487659454346
# Epoch: 5, Steps: 31 | Train Loss: 0.1124259 Vali Loss: 0.3629067 Test Loss: 32.7740898
# Validation loss decreased (0.475272 --> 0.362907).  Saving model ...
# Updating learning rate to 6.25e-06
# Epoch: 6 cost time: 4.270077228546143
# Epoch: 6, Steps: 31 | Train Loss: 0.1032283 Vali Loss: 0.3135440 Test Loss: 31.8412800
# Validation loss decreased (0.362907 --> 0.313544).  Saving model ...
# Updating learning rate to 3.125e-06
# >>>>>>>testing : informer_custom_ftMS_sl5_ll1_pl30_dm512_nh8_el2_dl1_df2048_atprob_fc5_ebtimeF_dtTrue_exp_0<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# test 44
# test shape: (6, 7, 30, 1) (6, 7, 30, 1)
# test shape: (42, 30, 1) (42, 30, 1)
# mse:31.568918228149414, rmse:5.618622303009033, mae:4.571770668029785
# Use CPU
# >>>>>>>start training : informer_custom_ftMS_s
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 6.25e-06
# Epoch: 6 cost time: 4.262589931488037
# Epoch: 6, Steps: 32 | Train Loss: 0.0849719 Vali Loss: 0.1897718 Test Loss: 30.2842903
# Validation loss decreased (0.196788 --> 0.189772).  Saving model ...
# Updating learning rate to 3.125e-06
# >>>>>>>testing : informer_custom_ftMS_sl7_ll1_pl25_dm512_nh8_el2_dl1_df2048_atprob_fc5_ebtimeF_dtTrue_exp_0<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# test 49
# test shape: (7, 7, 25, 1) (7, 7, 25, 1)
# test shape: (49, 25, 1) (49, 25, 1)
# mse:30.072290420532227, rmse:5.483820915222168, mae:4.323765754699707
# Use CPU
# >>>>>>>start training : informer_custom_ftMS_sl7_ll1_pl30_dm512_nh8_el2_dl1_df2048_atprob_fc5_ebtimeF_dtTrue_exp_0>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 219
# val 8
# test 44
# Epoch: 1 cost time: 4.334619760513306
# Epoch: 1, Steps: 31 | Train Loss: 0.5889921 Vali Loss: 0.7589687 Test Loss: 46.1174507
# Validation loss decreased (inf --> 0.758969).  Saving model ...
# Updating learning rate to 0.0001
# Epoch: 2 cost time: 4.251755237579346
# Epoch: 2, Steps: 31 | Train Loss: 0.2254056 Vali Loss: 0.5506489 Test Loss: 40.5166626
# Validation loss decreased (0.758969 --> 0.550649).  Saving model ...
# Updating learning rate to 5e-05
# Epoch: 3 cost time: 4.282868146896362
# Epoch: 3, Steps: 31 | Train Loss: 0.1523286 Vali Loss: 0.6169032 Test Loss: 39.7904930
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 2.5e-05
# Epoch: 4 cost time: 4.275910139083862
# Epoch: 4, Steps: 31 | Train Loss: 0.1382240 Vali Loss: 0.4160548 Test Loss: 37.4183350
# Validation loss decreased (0.550649 --> 0.416055).  Saving model ...
# Updating learning rate to 1.25e-05
# Epoch: 5 cost time: 4.2518150806427
# Epoch: 5, Steps: 31 | Train Loss: 0.1360666 Vali Loss: 0.3787014 Test Loss: 36.1156273
# Validation loss decreased (0.416055 --> 0.378701).  Saving model ...
# Updating learning rate to 6.25e-06
# Epoch: 6 cost time: 4.278520345687866
# Epoch: 6, Steps: 31 | Train Loss: 0.1028257 Vali Loss: 0.3258365 Test Loss: 35.6962471
# Validation loss decreased (0.378701 --> 0.325836).  Saving model ...
# Updating learning rate to 3.125e-06
# >>>>>>>testing : informer_custom_ftMS_sl7_ll1_pl30_dm512_nh8_el2_dl1_df2048_atprob_fc5_ebtimeF_dtTrue_exp_0<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# test 44
# test shape: (6, 7, 30, 1) (6, 7, 30, 1)
# test shape: (42, 30, 1) (42, 30, 1)
# mse:35.77241897583008, rmse:5.98100471496582, mae:4.9472551345825195
# Args in experiment:
# {'model': 'informer', 'data': 'custom', 'root_path': '/root/study/ChainMT/Informer/processed_data/2017/', 'data_path': 'betti.csv', 'features': 'MS', 'target': 'price', 'freq': 'h', 'checkpoints': './informer_checkpoints', 'seq_len': 7, 'label_len': 1, 'pred_len': 30, 'enc_in': 22, 'dec_in': 22, 'c_out': 1, 'factor': 5, 'd_model': 512, 'n_heads': 8, 'e_layers': 2, 'd_layers': 1, 'd_ff': 2048, 'dropout': 0.05, 'attn': 'prob', 'embed': 'timeF', 'activation': 'gelu', 'distil': True, 'output_attention': False, 'batch_size': 7, 'learning_rate': 0.0001, 'loss': 'rmse', 'lradj': 'type1', 'use_amp': False, 'num_workers': 0, 'itr': 1, 'train_epochs': 6, 'patience': 3, 'des': 'exp', 'use_gpu': False, 'gpu': 0, 'use_multi_gpu': False, 'devices': '0,1,2,3', 'detail_freq': 'h'}
# Use CPU
# >>>>>>>start training : informer_custom_ftMS_sl3_ll1_pl1_dm512_nh8_el2_dl1_df2048_atprob_fc5_ebtimeF_dtTrue_exp_0>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 252
# val 37
# test 73
# Epoch: 1 cost time: 3.4129483699798584
# Epoch: 1, Steps: 36 | Train Loss: 0.3873329 Vali Loss: 0.3153666 Test Loss: 33.7636528
# Validation loss decreased (inf --> 0.315367).  Saving model ...
# Updating learning rate to 0.0001
# Epoch: 2 cost time: 3.418123245239258
# Epoch: 2, Steps: 36 | Train Loss: 0.1247584 Vali Loss: 0.3450715 Test Loss: 32.7184677
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 5e-05
# Epoch: 3 cost time: 3
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 2.5e-05
# Epoch: 4 cost time: 4.124581336975098
# Epoch: 4, Steps: 32 | Train Loss: 0.0795597 Vali Loss: 0.3596486 Test Loss: 38.0540810
# EarlyStopping counter: 3 out of 3
# Early stopping
# >>>>>>>testing : informer_custom_ftMS_sl7_ll1_pl20_dm512_nh8_el2_dl1_df2048_atprob_fc5_ebtimeF_dtTrue_exp_0<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# test 54
# test shape: (7, 7, 20, 1) (7, 7, 20, 1)
# test shape: (49, 20, 1) (49, 20, 1)
# mse:36.41844940185547, rmse:6.0347700119018555, mae:5.028385162353516
# Use CPU
# >>>>>>>start training : informer_custom_ftMS_sl7_ll1_pl25_dm512_nh8_el2_dl1_df2048_atprob_fc5_ebtimeF_dtTrue_exp_0>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 224
# val 13
# test 49
# Epoch: 1 cost time: 4.425216913223267
# Epoch: 1, Steps: 32 | Train Loss: 0.6050809 Vali Loss: 0.4872589 Test Loss: 47.3172874
# Validation loss decreased (inf --> 0.487259).  Saving model ...
# Updating learning rate to 0.0001
# Epoch: 2 cost time: 4.424509525299072
# Epoch: 2, Steps: 32 | Train Loss: 0.1787742 Vali Loss: 0.4561152 Test Loss: 44.9680214
# Validation loss decreased (0.487259 --> 0.456115).  Saving model ...
# Updating learning rate to 5e-05
# Epoch: 3 cost time: 4.358706951141357
# Epoch: 3, Steps: 32 | Train Loss: 0.0786698 Vali Loss: 0.4216171 Test Loss: 42.6161880
# Validation loss decreased (0.456115 --> 0.421617).  Saving model ...
# Updating learning rate to 2.5e-05
# Epoch: 4 cost time: 4.392349720001221
# Epoch: 4, Steps: 32 | Train Loss: 0.0590740 Vali Loss: 0.2032450 Test Loss: 42.4997597
# Validation loss decreased (0.421617 --> 0.203245).  Saving model ...
# Updating learning rate to 1.25e-05
# Epoch: 5 cost time: 4.335738658905029
# Epoch: 5, Steps: 32 | Train Loss: 0.0566006 Vali Loss: 0.3988914 Test Loss: 42.6614876
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 6.25e-06
# Epoch: 6 cost time: 4.326119422912598
# Epoch: 6, Steps: 32 | Train Loss: 0.0520701 Vali Loss: 0.4588066 Test Loss: 42.8162842
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 3.125e-06
# >>>>>>>testing : informer_custom_ftMS_sl7_ll1_pl25_dm512_nh8_el2_dl1_df2048_atprob_fc5_ebtimeF_dtTrue_exp_0<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# test 49
# test shape: (7, 7, 25, 1) (7, 7, 25, 1)
# test shape: (49, 25, 1) (49, 25, 1)
# mse:42.53382110595703, rmse:6.521795749664307, mae:5.563535690307617
# Use CPU
# >>>>>>>start training : informer_custom_ftMS_sl7_ll1_pl30_dm512_nh8_el2_dl1_df2048_atprob_fc5_ebtimeF_dtTrue_exp_0>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 219
# val 8
# test 44
# Epoch: 1 cost time: 4.514942646026611
# Epoch: 1, Steps: 31 | Train Loss: 0.3340807 Vali Loss: 0.2824710 Test Loss: 40.0777550
# Validation loss decreased (inf --> 0.282471).  Saving model ...
# Updating learning rate to 0.0001
# Epoch: 2 cost time: 4.365339994430542
# Epoch: 2, Steps: 31 | Train Loss: 0.1840120 Vali Loss: 0.1517788 Test Loss: 35.6752434
# Validation loss decreased (0.282471 --> 0.151779).  Saving model ...
# Updating learning rate to 5e-05
# Epoch: 3 cost time: 4.43613600730896
# Epoch: 3, Steps: 31 | Train Loss: 0.1265431 Vali Loss: 0.3532589 Test Loss: 41.9565125
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 2.5e-05
# Epoch: 4 cost time: 4.364176034927368
# Epoch: 4, Steps: 31 | Train Loss: 0.0672716 Vali Loss: 0.4423447 Test Loss: 42.9939613
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 1.25e-05
# Epoch: 5 cost time: 4.457424640655518
# Epoch: 5, Steps: 31 | Train Loss: 0.0682512 Vali Loss: 0.3034567 Test Loss: 41.3814697
# EarlyStopping counter: 3 out of 3
# Early stopping
# >>>>>>>testing : informer_custom_ftMS_sl7_ll1_pl30_dm512_nh8_el2_dl1_df2048_atprob_fc5_ebtimeF_dtTrue_exp_0<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# test 44
# test shape: (6, 7, 30, 1) (6, 7, 30, 1)
# test shape: (42, 30, 1) (42, 30, 1)
# mse:35.7523078918457, rmse:5.979323387145996, mae:4.986961841583252

# %%
np.save("/root/study/ChainMT/Informer/2017_bitcoin_informer_rmse_total.npy", rmse_total)
